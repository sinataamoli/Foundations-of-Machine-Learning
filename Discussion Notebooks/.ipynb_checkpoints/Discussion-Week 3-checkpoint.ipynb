# %% [markdown]
# # ============================

# %% [markdown]
# # Week 3

# %% [markdown]
# # ============================

# %% [markdown]
# # -----------------------------------------

# %% [markdown]
# ## Object Oriented Programming in Python

# %% [markdown]
# # -----------------------------------------

# %% [markdown]
# ## Python Class

# %% [markdown]
# ### 1. Objects and Methods

# %% [markdown]
# let's define a class "dog", and the operations that a dog is able to to, like barking. We call these operations "methods" (functions inside a class):<br>

# %% [markdown]
# # -----------------------------------------

# %% [markdown]
# ## Introduction to Statistics

# %% [markdown]
# # -----------------------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt

# font parameters dictionary
font = {'family' : 'serif',
        'weight' : 'bold',
        'size'   : 25,}


# figure parameters dictionary
figure = {"figsize" : (6,6),
          "dpi" : 120,
          "facecolor" : "w", 
          "edgecolor" : "k",}



# use LaTeX fonts in the plot
plt.rc('text', usetex=True)

# Set the font parameters
plt.rc('font', **font)

# %% [markdown]
# First, we are going to define a gaussian function. We can use built-in functions in numpy for getting a gaussian function. However, let's define it ourself  as a practice:

# %%
def Gaussian_prob_dist(x, _mu = 0, _sigma = 1):
    """ Gaussian Distribution: The probability of getting x given _mu, _sigma """
    return (1 / np.sqrt(2 * np.pi * sigma**2)) * np.exp(-(x - _mu)**2 / (2 * _sigma**2))

# %%
# Initialize

x_span = np.linspace(0, 20, 1000)
mu, sigma = 10, 5

prob_list = [Gaussian_prob_dist(x, mu, sigma) for x in x_span]

# %% [markdown]
# Another equivalent way of doing the above but using the numpy arrays. (Be very careful when writing code this way, since the code above works for any iterable object; but, the method used below can only be applied for the numpy array object and not a list.

# %%
plt.figure(figsize = (8, 8))
plt.plot(x_span, prob_list)

plt.title("Gaussian Distribution for x_span with given $\mu$ and $\sigma$", fontsize = 20)
plt.xlabel(r"x", fontsize = 18)
plt.ylabel(r"$P(x| \mu, \sigma)$", fontsize = 18)

plt.show()

# %% [markdown]
# ### A new particle is discovered in CERN!

# %% [markdown]
# $$
# \begin{gather}
# M_{ATLAS} = 10.12 \pm 3.7 \\
# M_{CMS} = 7.42 \pm 1.6
# \end{gather}
# $$

# %% [markdown]
# #### Q: What should be reported to the public as the new particle's mass?

# %%
mass_atlas, mass_err_atlas = 10.12, 3.7
mass_cms, mass_err_cms = 7.42, 1.6

# %%
report_1 = (mass_atlas + mass_cms) / 2
report_1
# Out:
# 8.77

# %% [markdown]
# $ X_1 $: mass_atlas, mass_err_atlas
# $ X_2 $: mass_cms, mass_err_cms

# %% [markdown]
# ### Bayes Theorem

# %% [markdown]
# Bayes Theorem: $p(m_{x}| X_{1}, X_{2}) \varpropto p(X_{1}, X_{2}|m_{x})$

# %% [markdown]
# More precisely:

# %% [markdown]
# $P(X|Y) = \frac{P(Y | X) P(X)}{P(Y)}$

# %% [markdown]
# ### Assumptions

# %% [markdown]
# 1- The measurements are independent <br>
# $P(X_{1}, X_{2} | m_{x}) = P(X_{1} | m_{x}) * p(X_{2} | m_{x})$

# %% [markdown]
# 2- Measurements follow a Normal Distribution
# $PDF(m_{\text{measured}}) = Gaussian(m_{\text{measured}}, \sigma_{\text{measured}})$

# %% [markdown]
# 3- no info about $m_{x}$: the simplest choice: uniform PDF (Top Hat)

# %% [markdown]
# let's calculate $p(X_{1} | m_{x})$:

# %% [markdown]
# We start by sampling potential values for $m_{X}$:

# %%
m_X_span = np.arange(0, 25, 0.001)

# %% [markdown]
# Making two arrays of zeros for storing the probabilities

# %%
prob_atlas = np.zeros(len(m_X_span))
prob_cms = np.zeros(len(m_X_span))

# %% [markdown]
# Building the joint pdf [p(X1, X2)]

# %%
for i, m in enumerate(m_X_span):
    prob_atlas[i] = Gaussian_prob_dist(mass_atlas, _mu = m, _sigma = mass_err_atlas)
    prob_cms[i] = Gaussian_prob_dist(mass_cms, _mu = m, _sigma = mass_err_cms)

# %% [markdown]
# Find the joint probability

# %%
joint_prob = prob_atlas * prob_cms
joint_prob
# Out:
# array([3.23111642e-09, 3.24289078e-09, 3.25470654e-09, ...,
#        1.22205269e-32, 1.21237231e-32, 1.20276805e-32])

# %%
Normalization = len(m_X_span) / (sum(joint_prob) * (max(m_X_span) - min(m_X_span)))
joint_prob_normalized = joint_prob * Normalization

# %% [markdown]
# Finding the mass corresponding to the highest probability:

# %%
m_X_max_prob = m_X_span[joint_prob == max(joint_prob)]
print("The value with the maximum probability is: ", m_X_max_prob[0])
# Out:
# The value with the maximum probability is:  7.845

# %% [markdown]
# plotting the pdf for the two measurements + joint pdf (normalized and unnormalized):

# %%
plt.figure(figsize = (8, 8))

plt.plot(m_X_span, prob_atlas, label = "ATLAS TEAM")
plt.plot(m_X_span, prob_cms, label = "CMS TEAM")

plt.plot(m_X_span, joint_prob, label = "Joint probability (Not normalized)")
plt.plot(m_X_span, joint_prob_normalized, label = "Joint probability (normalized)")

plt.vlines(report_1, 0, 0.27, color = 'blue', linestyles="dashed", label="Average of ATLAS and CMS")
plt.vlines(m_X_max_prob, 0, 0.27, color = 'black', linestyles="dashed", label="Max Probability")

plt.title(r"Prob. Dist. Funct.", fontsize = 20)
plt.xlabel(r"$m_{x}$", fontsize = 19)
plt.ylabel(r"Probability", fontsize = 18)

plt.legend(fontsize = 14)

plt.show()

# %% [markdown]
# The analytical way of finding this result is simple as we are working with Gaussian Functions:

# %% [markdown]
# The probability of two Gaussians (independent) is a Gaussian PDF

# %% [markdown]
# $Gaussian(\mu = \frac{\mu_{1} \sigma_{2}^{2} + \mu_{2}\sigma_{1}^{2}}{\sigma_{1}^{2}+\sigma_{2}^{2}}, \sigma = \frac{\sigma_{1}\sigma_{2}}{\sqrt{\sigma_{1}^{2} +\sigma_{2}^{2}}}) = Gaussian (\mu_{1}, \sigma_{1}) \times Gaussian (\mu_{2}, \sigma_{2})$

# %% [markdown]
# # ============================

# %% [markdown]
# # Week 4

# %% [markdown]
# # ============================

# %% [markdown]
# ## Fitting a model to given data using Least Suared Method

# %% [markdown]
#  <center> $y = f(x) = \alpha x e^{\gamma x}$

# %%
from math import exp
import numpy as np
import matplotlib.pyplot as plt

def f(x, α, γ):
    return α * x * exp(γ * x)

# %%
np.random.seed(5)

α, γ = 0.5, 0.5

x_span = [i / 100 for i in range(-200, 200, 10)]
y_span = [f(i, α, γ) + 0.1 * np.random.randn() for i in x_span]

plt.figure(figsize = (8, 8))

plt.plot(x_span, y_span, ".")

plt.show()

# %%
def least_squared(y_measured, y_prediction):
    ls = []
    
    for y0, y1 in zip(y_measured, y_prediction):
        ls.append((y0 - y1)**2)
        
    return sum(ls)**0.5

# %%
def prob(l):
    return exp(-l**2)

# %%
α_span = np.linspace(0.2, 0.8, 300)
γ_span = np.linspace(0.2, 0.9, 300)

# %%
values = []

for α in α_span:
    for γ in γ_span:
        y_prediction = [f(x, α, γ) for x in x_span]
        y_measured = y_span
        values.append((prob(least_squared(y_measured, y_prediction)), α, γ))

# %% [markdown]
# we want to find the pairs sorted with respect to their probability

# %%
sorted(values, key = lambda x: x[0], reverse = True)[:5]
# Out:
# [(0.740783164906095, 0.4929765886287626, 0.5254180602006688),
#  (0.7407383302038685, 0.4949832775919733, 0.523076923076923),
#  (0.7406791270131042, 0.4909698996655519, 0.5277591973244147),
#  (0.7405525627824976, 0.4929765886287626, 0.523076923076923),
#  (0.7405433463379689, 0.496989966555184, 0.5207357859531773)]

# %%
A, B = sorted(values, key=lambda x : x[0], reverse=True)[0][1], sorted(values, key=lambda x : x[0], reverse=True)[0][2]

# %%
A, B
# Out:
# (0.4929765886287626, 0.5254180602006688)

# %% [markdown]
# ### Plotting the probability density: $p(\alpha, \gamma | data)$

# %%
X = [value[1] for value in values]
Y = [value[2] for value in values]
Z = [value[0] for value in values]

fig = plt.figure(figsize = (12, 10))
ax = fig.add_subplot(1, 1, 1)
ax.set_title(r"2D Probability Distribution $P(\alpha, \gamma |data)$")
c = ax.scatter(X, Y, c = Z, cmap = 'turbo')

ax.set_xlabel(r"$\alpha$", fontsize = 23)
ax.set_ylabel(r"$\gamma$", fontsize = 23)

plt.colorbar(c)
plt.show()

# %%
from mpl_toolkits import mplot3d

plt.figure(figsize = (12, 12))

ax = plt.axes(projection = '3d', )
ax.view_init(azim = 120, elev = 20)

ax.scatter3D(X, Y, Z, c = Z, cmap = 'turbo')

ax.set_title(r"3D prob. dist.", y = 1.01)

ax.set_xlabel(r"$\alpha$")
ax.set_ylabel(r"$\gamma$")
ax.set_zlabel(r"$P(\alpha, \gamma |data)$", labelpad = 2)

plt.show()

# %%
plt.figure(figsize = (8, 8))

plt.plot(x_span, y_span, ".", label = "data points")
plt.plot(x_span, [f(x, A, B) for x in x_span], label="Best fitted line")

plt.legend()
plt.show()

# %% [markdown]
# ## Bayesian Inference

# %%
data = np.array([16, 24, 16, 12, 16, 11, 14, 15, 9, 14, 7])

# %%
plt.figure(figsize = (13, 6))

labels, counts = np.unique(data, return_counts = True)

plt.bar(labels, counts, align = 'center')
plt.xticks(range(6, 25))
plt.yticks(range(1, 4))
plt.tick_params(labelsize = 20)

# %% [markdown]
# ### Poisson Distribution is reasonable choice

# %% [markdown]
# <center> $p(k | \lambda) = \frac{\lambda^{k} e^{-\lambda}}{k!}$

# %%
from math import factorial

# %%
@np.vectorize
def poisson(k, λ=2):
    return λ**k * np.exp(-λ) / factorial(k)

# %%
ks = np.arange(0, 25)
ps = poisson(ks, 2.2)

# %%
plt.figure(figsize = (14, 9))

for λ in [0.5, 1, 1.5, 2, 5, 10]:
    ps = poisson(ks, λ)
    plt.plot(ks, ps, label = r"$\lambda = {}$".format(λ))
    plt.scatter(ks, ps, s = 50)
    
plt.xticks(ks)
plt.legend(fontsize = 20)
plt.tick_params(labelsize = 22)

# %% [markdown]
# ### Model:

# %% [markdown]
# <center> $p(\lambda) = \frac{1}{\lambda_{max}- \lambda_{min}}$

# %% [markdown]
# <center> $p(k | \lambda) = \frac{\lambda^{k} e^{-\lambda}}{k!}$

# %% [markdown]
# #### Bayesian

# %% [markdown]
# <center> $p(\lambda|data) \propto p(data |\lambda) * p(\lambda)$

# %% [markdown]
# <center> $p(data | \lambda) = \prod_{k} p(k | \lambda)$

# %% [markdown]
# <center> $ln(p(\lambda | data)) \propto \sum_{k} ln(p(k|\lambda)) + ln(p(\lambda))$

# %%
@np.vectorize
def ln_prior(λ, MIN, MAX):
    p = 1 / (MAX - MIN)
    if MIN <= λ <= MAX:
        return np.log(p)
    else:
        return -np.inf

# %%
def ln_likelihood(ks, λ):
    return np.sum(np.log(poisson(ks, λ)))

# %%
MIN, MAX = 0.001, 100
λ_span = np.linspace(MIN, MAX, 3000)

# %%
ln_posterior = []
ln_likelihoods = []

Π_min, Π_max = 5, 20

for λ in λ_span:
    ln_posterior += [ln_prior(λ, Π_min, Π_max) + ln_likelihood(data, λ)]
    ln_likelihoods += [ln_likelihood(data, λ)]
    
ln_posterior = np.array(ln_posterior)
ln_likelihoods = np.array(ln_likelihoods)

# %%
from scipy.integrate import trapz

# %%
posterior_probability = np.exp(ln_posterior) / trapz(np.exp(ln_posterior), λ_span)

likelihoods = (np.exp(ln_likelihoods) / np.exp(ln_likelihoods).max() * max(posterior_probability))

prior = np.exp(ln_prior(λ_span, Π_min, Π_max))

# %%
MAP_estimate = float(λ_span[posterior_probability == posterior_probability.max()])

# %%
MAP_estimate
# Out:
# 14.005528176058684

# %%
data.mean()
# Out:
# 14.0

# %%
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(1, 1, 1)
ax.plot(λ_span, prior, label="Prior Probability", color="darkblue", lw=3)
ax.plot(λ_span, posterior_probability, label="Posterior Probability", color="r", lw=3)

ax.vlines(data.mean(), *plt.gca().get_ylim(), label=r"Average of the data $={}$".format(round(data.mean(), 2)), color="g", ls="--", lw=4)

ax.vlines(MAP_estimate, 0, posterior_probability.max(), label=r"MAP estimate is $\lambda = {}$".format(round(MAP_estimate, 2)), color="r", lw=4, alpha=0.5)

ax.tick_params(labelsize=25)

ax.set_xlabel(r"$\lambda$", fontsize=32)
ax.set_ylabel(r"$p(\lambda \mid data)$", fontsize=32)

ax.set_xlim(-1, 42)

ax.legend(fontsize=22, frameon=False, loc="upper right");
